# %% [markdown]
# ***Read table using sql***

# %%
# %sql
select * from samples.nyctaxi.trips

# %% [markdown]
# ***Read table using pyspark***

# %%
display(spark.read.table('samples.nyctaxi.trips'))
